# %% [markdown]
# <a href="https://colab.research.google.com/github/AgaWoj/data_science/blob/main/PorownanieDoSql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !ls -la '/content/drive/My Drive/Colab Notebooks/DataScience2024TKrakowiakBootcomp'
# Out:
# total 48760
# -rw------- 1 root root 23948849 Feb  3 12:30 appstore_games.csv
# -rw------- 1 root root   190394 Feb  4 18:53 AppStoreGames.ipynb
# -rw------- 1 root root   448927 Jan 30 21:12 DaneGieldowe.ipynb
# -rw------- 1 root root   215228 Feb  1 07:02 LACZENIEDANYCH.ipynb
# -rw------- 1 root root  1052236 Jan 29 19:07 london_bike.csv
# -rw------- 1 root root    25124 Jan 29 19:17 LondonBike.ipynb
# -rw------- 1 root root   120274 Jan 10 06:56 NumPyIntro.ipynb
# -rw------- 1 root root 23715344 Feb  5 18:00 online_retail.xlsx
# -rw------- 1 root root   138499 Jan 15 18:13 PandasIntro.ipynb
# -rw------- 1 root root    72300 Feb  6 06:35 PorównanieDoSql.ipynb

# %%
data = '/content/drive/My Drive/Colab Notebooks/DataScience2024TKrakowiakBootcomp/online_retail.xlsx'
df_row = pd.read_excel(data)
df_row.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df_row.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df = df_row.copy()

# %%
df.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df.describe(include=['object']).T
# Out:
#               count unique                                 top    freq
# InvoiceNo    541909  25900                              573585    1114
# StockCode    541909   4070                              85123A    2313
# Description  540455   4223  WHITE HANGING HEART T-LIGHT HOLDER    2369
# Country      541909     38                      United Kingdom  495478

# %%
# sprawdzam braki danych w obiekcie df, po isnull() daj sum() to pokaże ile wkażdej kolumnie brakuje jak brakuje

df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# decyduje się na usunięcie braków danych ale tracę 135 080 wierszy? są inne metody wypełnienie tekstem 'brak danych', średnią itd.

df = df.dropna()
df.info()

# inne rozwiązanie - jak wypełnić braki danych
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    406829 non-null  object
#  1   StockCode    406829 non-null  object
#  2   Description  406829 non-null  object
#  3   Quantity     406829 non-null  int64
#  4   InvoiceDate  406829 non-null  datetime64[ns]
#  5   UnitPrice    406829 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      406829 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.9+ MB

# %%
# jak usunąć dane gdzie zmienna wiekość jest ujemaną
# wytnij do maski logicznej
# i muszę to nadpisać df

df = df[df.Quantity >= 0]
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.Quantity.value_counts()
# Out:
# 1        73314
# 12       60033
# 2        58003
# 6        37688
# 4        32183
#          ...
# 4300         1
# 608          1
# 738          1
# 552          1
# 80995        1
# Name: Quantity, Length: 302, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 397924 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    397924 non-null  object
#  1   StockCode    397924 non-null  object
#  2   Description  397924 non-null  object
#  3   Quantity     397924 non-null  int64
#  4   InvoiceDate  397924 non-null  datetime64[ns]
#  5   UnitPrice    397924 non-null  float64
#  6   CustomerID   397924 non-null  float64
#  7   Country      397924 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.3+ MB

# %%
# CustomerID jest float64 a chcę aby był typ tekstowy
# pierwsze przekonwertuje na liczbę całkowitą a później na tekst

df.CustomerID = df.CustomerID.apply(lambda x: str(int(x)))

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice CustomerID         Country
# 0 2010-12-01 08:26:00       2.55      17850  United Kingdom
# 1 2010-12-01 08:26:00       3.39      17850  United Kingdom
# 2 2010-12-01 08:26:00       2.75      17850  United Kingdom
# 3 2010-12-01 08:26:00       3.39      17850  United Kingdom
# 4 2010-12-01 08:26:00       3.39      17850  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 397924 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    397924 non-null  object
#  1   StockCode    397924 non-null  object
#  2   Description  397924 non-null  object
#  3   Quantity     397924 non-null  int64
#  4   InvoiceDate  397924 non-null  datetime64[ns]
#  5   UnitPrice    397924 non-null  float64
#  6   CustomerID   397924 non-null  object
#  7   Country      397924 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 27.3+ MB

# %%
df.describe(include=['object']).T
# Out:
#               count unique                                 top    freq
# InvoiceNo    397924  18536                              576339     542
# StockCode    397924   3665                              85123A    2035
# Description  397924   3877  WHITE HANGING HEART T-LIGHT HOLDER    2028
# CustomerID   397924   4339                               17841    7847
# Country      397924     37                      United Kingdom  354345

# %% [markdown]
# ## Porównanie SQL z Pandas

# %%
# SELECT * FROM retail;
# wydobądź wszystkie dane z obiektu DataFrame, w Pandas to tylko wywołanie obiektu

df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country
# ...

# %%
# SELECT Quantity, UnitPrice, CustomerID FROM retial;
# odpytanie tabeli o poszczególne kolumny
# przekazujemy df i podajemy w [[]] listę kolumn które chcę wyciąć

df[['Quantity', 'UnitPrice', 'CustomerID']]
# Out:
#         Quantity  UnitPrice CustomerID
# 0              6       2.55      17850
# 1              6       3.39      17850
# 2              8       2.75      17850
# 3              6       3.39      17850
# 4              6       3.39      17850
# ...          ...        ...        ...
# 541904        12       0.85      12680
# 541905         6       2.10      12680
# 541906         4       4.15      12680
# 541907         4       4.15      12680
# 541908         3       4.95      12680
#
# [397924 rows x 3 columns]

# %%
# SELECT Quantity, UnitPrice, CustomerID FROM retial LIMIT 10;
# odpytanie tabeli o poszczególne kolumny
# przekazujemy df i podajemy w [[]] listę kolumn które chcę wyciąć

df[['Quantity', 'UnitPrice', 'CustomerID']].head(10)
# Out:
#    Quantity  UnitPrice CustomerID
# 0         6       2.55      17850
# 1         6       3.39      17850
# 2         8       2.75      17850
# 3         6       3.39      17850
# 4         6       3.39      17850
# 5         2       7.65      17850
# 6         6       4.25      17850
# 7         6       1.85      17850
# 8         6       1.85      17850
# 9        32       1.69      13047

# %%
# lub

df[['Quantity', 'UnitPrice', 'CustomerID']][:10]
# Out:
#    Quantity  UnitPrice CustomerID
# 0         6       2.55      17850
# 1         6       3.39      17850
# 2         8       2.75      17850
# 3         6       3.39      17850
# 4         6       3.39      17850
# 5         2       7.65      17850
# 6         6       4.25      17850
# 7         6       1.85      17850
# 8         6       1.85      17850
# 9        32       1.69      13047

# %%
# SELECT * FROM retial WHERE CustomerID='17850';

df[df.CustomerID == '17850']
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 4540    536790     22752         SET 7 BABUSHKA NESTING BOXES         4
# 4541    536790     22803             IVORY EMBROIDERED QUILT          3
# 4542    536790     21730    GLASS STAR FROSTED T-LIGHT HOLDER        12
# 4543    536791     22632            HAND WARMER RED POLKA DOT        12
# 4544    536791     22633               HAND WARMER UNION JACK        12
#
#              InvoiceDate  UnitPrice CustomerID         Country
# ...

# %%
# lub query

df.query('CustomerID == "17850"')
# Out:
#      InvoiceNo StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 4540    536790     22752         SET 7 BABUSHKA NESTING BOXES         4
# 4541    536790     22803             IVORY EMBROIDERED QUILT          3
# 4542    536790     21730    GLASS STAR FROSTED T-LIGHT HOLDER        12
# 4543    536791     22632            HAND WARMER RED POLKA DOT        12
# 4544    536791     22633               HAND WARMER UNION JACK        12
#
#              InvoiceDate  UnitPrice CustomerID         Country
# ...

# %%
# instrukcje warunkowe
# SELECT * FROM retial WHERE CustomerID='17850' and UnitPrice > 5;
# dwie maski logiczne w oddzielnych nawiasach

df[(df.CustomerID == '17850') & (df.UnitPrice > 5)]
# Out:
#      InvoiceNo StockCode                        Description  Quantity  \
# 5       536365     22752       SET 7 BABUSHKA NESTING BOXES         2
# 58      536373     82486  WOOD S/3 CABINET ANT WHITE FINISH         4
# 63      536373     22752       SET 7 BABUSHKA NESTING BOXES         2
# 75      536375     82486  WOOD S/3 CABINET ANT WHITE FINISH         4
# 80      536375     22752       SET 7 BABUSHKA NESTING BOXES         2
# 288     536396     82486  WOOD S/3 CABINET ANT WHITE FINISH         4
# 293     536396     22752       SET 7 BABUSHKA NESTING BOXES         2
# 294     536396     22803           IVORY EMBROIDERED QUILT          2
# 425     536406     82486  WOOD S/3 CABINET ANT WHITE FINISH         4
# 430     536406     22752       SET 7 BABUSHKA NESTING BOXES         2
# 431     536406     22803           IVORY EMBROIDERED QUILT          2
# 3121    536600     82486  WOOD S/3 CABINET ANT WHITE FINISH         2
# ...

# %%
# SELECT * FROM retial WHERE CustomerID='17850' or Country='France';

df[(df.CustomerID == '17850') | (df.Country == 'France')]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country
# ...

# %%
# SELECT * FROM retail WHERE InvoiceNo is not null;

df[df.InvoiceNo.notnull()]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice CustomerID         Country
# ...

# %%
# isnull jak chcę wyciąć braki danych

df[df.InvoiceNo.isnull()]

#. nie ma braków danych w tej kolumnie
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []
